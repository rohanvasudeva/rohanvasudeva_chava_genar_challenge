# %%
# some necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# install openpyxl
df = pd.read_excel("../data/Bisoprolol_icsr_sample_1068rows.xlsx")

# %%
df.shape
# Out:
# (1068, 67)

# %%
df.head()
# Out:
#    safetyreportversion  safetyreportid primarysourcecountry    occurcountry  \
# 0                    1        24780403                italy           italy
# 1                    1        24780599               france          france
# 2                    1        24780680               france          france
# 3                    1        24784771       united kingdom  united kingdom
# 4                    1        24784845       united kingdom  united kingdom
#
#    transmissiondateformat  transmissiondate          reporttype  serious  \
# 0                     102          20250115  spontaneous report  serious
# 1                     102          20250115  spontaneous report  serious
# 2                     102          20250114  spontaneous report  serious
# 3                     102          20250114  spontaneous report  serious
# 4                     102          20250114  spontaneous report  serious
#
#   seriousnessdeath seriousnesslifethreatening  ...  \
# ...

# %%
df.columns.tolist()
# Out:
# ['safetyreportversion',
#  'safetyreportid',
#  'primarysourcecountry',
#  'occurcountry',
#  'transmissiondateformat',
#  'transmissiondate',
#  'reporttype',
#  'serious',
#  'seriousnessdeath',
#  'seriousnesslifethreatening',
#  'seriousnesshospitalization',
#  'seriousnessdisabling',
#  'seriousnesscongenitalanomali',
#  'seriousnessother',
#  'receivedateformat',
#  'receivedate',
#  'receiptdateformat',
#  'receiptdate',
#  'fulfillexpeditecriteria',
#  'companynumb',
#  'primarysource_reportercountry',
#  'primarysource_qualification',
#  'sender_sendertype',
#  'sender_senderorganization',
#  'receiver_receivertype',
#  'receiver_receiverorganization',
#  'patient_patientonsetage',
#  'patient_patientonsetageunit',
#  'patient_patientsex',
#  'patient_reaction_reactionmeddraversionpt',
#  'patient_reaction_reactionmeddrapt',
#  'patient_reaction_reactionoutcome',
#  'patient_drug_drugcharacterization',
#  'patient_drug_medicinalproduct',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 67 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   safetyreportversion                               1068 non-null   int64
#  1   safetyreportid                                    1068 non-null   int64
#  2   primarysourcecountry                              1068 non-null   str
#  3   occurcountry                                      1061 non-null   str
#  4   transmissiondateformat                            1068 non-null   int64
#  5   transmissiondate                                  1068 non-null   int64
#  6   reporttype                                        1068 non-null   str
#  7   serious                                           1068 non-null   str
#  8   seriousnessdeath                                  1068 non-null   str
# ...

# %%
df["safetyreportid"].nunique()
# Out:
# 1024

# %%
# checking all cases
print("Total rows:", len(df))
print("Unique cases:", df["safetyreportid"].nunique())
print("Duplicate case rows:", df["safetyreportid"].duplicated().sum())
# Out:
# Total rows: 1068
# Unique cases: 1024
# Duplicate case rows: 44

# %%
# reactions for each case
reaction_counts = df.groupby("safetyreportid").size()
reaction_counts.value_counts().sort_index()
# Out:
# 1    983
# 2     38
# 3      3
# Name: count, dtype: int64
